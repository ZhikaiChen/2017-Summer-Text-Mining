# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/Users/chenzhikai/hdw_2017/printer_metadata/Relational database/')

# %%
pd.read_csv('printers.csv',index_col=0).fillna('').head()
# Out:
#      dlps                                          publisher
# 0  A00648  Printed by G. Eld for Roger Barnes, and are to...
# 1  A00908              Imprinted with licence by A. Conincx,
# 2  A01003  Printed by Richard Field for Felix Norton and ...
# 3  A01076  Printed by B. Alsop for Nathaniel Butter, and ...
# 4  A01086           Printed for Henry Tomes i.e. W. Jaggard,

# %%
#apply on a string, return a list of strings (info after signalling words)
def applysplitters(splitters, s):
    val = s
    for (find,replace) in splitters:
        val = re.sub(find, "|"+replace+r"\1", val)
    return [phrase for phrase in val.split("|") if phrase != '']

# %%
'''Split original publisher fields into printer, publisher, seller, based on keywords, by, for, sold by
and create new columns for their locations and institutional affiliations'''
def preproccess():
    
    df=pd.read_csv('printers.csv',index_col=0).fillna('')
    df.replace(':','',regex=True,inplace=True)
    #get rid of ... and strip trialing punctunations

    df.publisher=df.publisher.replace(r'\.\.\.','')
    df.publisher=df.publisher.str.strip(': ;?')
    # {m,n}? captures matched patterns from length m to length n, as few as possible
    # re.findall("regex()()") returns [($1,$2),($1,$2),...]
    #Preprocess to change "printed and sold by J. Bradford" into "printed by J. Bradford and sold by J. Bradford"
    df.publisher=df.publisher.str.replace('^(?:[EeIij][mn])?[Pp][ir][iye]nt[ye]d and [Ssh]?ou?lde? by ([A-Z](?:\.|[a-z]+\.?) ?)([A-Z](?:\.|[a-z]+\.?)),?',
                             r'printed by '+r'\g<1>'+r'\g<2>'+' and sold by '+r'\g<1>'+r'\g<2>')                             
    
    # use key words 'printed', 'for', 'are sold to' to create three fields
    splitters = [["((\\b[EeIij][mn])?[Pp][ir][iye]nt[ye]d\\b)", "printer:"],
                 ["(\\bfor\\b)", "publisher:"],
                 ["(( are)?( to)?( bee?)? [Ssh]ou?lde?)", "seller:"]]
    # list of list of strings of splitted fields
    l=map(lambda x:applysplitters(splitters,x),df.publisher)
    #create a list of dictionaries 
    output=[]
    for sublist in l:
        d ={}
        for item in sublist:
            if ':' in item:
                (k,v)=item.split(':')
            else:
                k,v = 'printer',item
            if k in d.keys():
                d[k]+=v
            else:
                d[k]=v
        output.append(d)
    Three_field=pd.DataFrame(output)
    Three_field['key']=df['dlps']
    
    #start to clean up the printer field
    Three_field.printer=Three_field.printer.str.replace(r'\.\.\.','')
    Three_field.printer=Three_field.printer.str.strip(': ;')
    # split printer field along location printer info and keyword 'by'

    df_new=Three_field.printer.str.extract(
    r'(?P<printer_location>^(?:\b[Ii]n\b|\b[Aa]t\b|\b[Ww]ithin\b|\b[Nn]eare?\b|\b[Dd]w[ey]ll[iy]nge?\b|\b[Aa]gainst\b|\b[Oo]ver\b|\b[Uu]nder\b).*)(?P<printer_y> ?\b[Bb]y\b,?.*)'
    ,expand=True)
    df_gesamt = pd.concat([Three_field,df_new], axis=1,
                      join ='outer')
    mask = df_gesamt['printer_y'].notnull()
    df_gesamt['printer'][mask] = df_gesamt['printer_y'][mask]
    df_gesamt.drop('printer_y',axis=1, inplace=True)
    
    # separate  printer from location based on location keywords
    df_new=df_gesamt.printer.str.extract(
        r'(?P<printer_y>.*?)(?P<printer_location_y>(?:\b[Ii]n\b|\b[Aa]t\b|\b[Ww]ithin\b|\b[Nn]eare?\b|\b[Dd]w[ey]ll[iy]nge?\b|\b[Aa]gainst\b|\b[Oo]ver\b|\b[Uu]nder\b).*)'
    ,expand=True) 
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')

    mask = df_gesamt['printer_y'].notnull()
    df_gesamt['printer'][mask] = df_gesamt['printer_y'][mask]
    mask = df_gesamt['printer_location_y'].notnull()
    df_gesamt['printer_location'][mask] = df_gesamt['printer_location_y'][mask]
    df_gesamt.drop(['printer_y','printer_location_y'],axis=1, inplace=True)
    
    #extract printer enclosed by location info in printer_location field 
    #'In London, xx, dwelling at xx'
    df_new=df_gesamt.printer_location.str.extract(r'(?P<printer_location_y>^(?:.*))(?P<printer_y> ?\b[Bb]y\b,? .*)')
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')

    mask = df_gesamt['printer_location_y'].notnull()
    df_gesamt['printer'][mask] = df_gesamt['printer'][mask]+df_gesamt['printer_y'][mask]
    df_gesamt['printer_location'][mask] = df_gesamt['printer_location_y'][mask]
    df_gesamt.drop(['printer_y','printer_location_y'],axis=1, inplace=True)

    
    #for cases like in London, by xx, dwelling at
    #put by xx in printer field, concat in London and dwelling at and put them into loc field
    df_new=df_gesamt.printer.str.extract(
        r'(?P<printer_y>.*?)(?P<printer_location_y>(?:\b[Ii]n\b|\b[Aa]t\b|\b[Ww]ithin\b|\b[Nn]eare?\b|\b[Dd]w[ey]ll[iy]nge?\b|\b[Aa]gainst\b|\b[Oo]ver\b|\b[Uu]nder\b).*)'
    ,expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')

    mask = df_gesamt['printer_location_y'].notnull()
    df_gesamt['printer'][mask] = df_gesamt['printer_y'][mask]
    df_gesamt['printer_location'][mask] = df_gesamt['printer_location_y'][mask]+df_gesamt['printer_location'][mask]
    df_gesamt.drop(['printer_y','printer_location_y'],axis=1, inplace=True)
    
    #Put stuffs in printer field started with "For" into publisher field
    df_new=df_gesamt.printer.str.extract('(?P<publisher_y> ?For .*)',expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                     join ='outer')

    mask = df_gesamt['publisher_y'].notnull()
    df_gesamt['publisher'][mask] = df_gesamt['publisher_y'][mask]
    df_gesamt['printer'][mask]=''
    df_gesamt.drop('publisher_y', inplace=True,axis=1)
    
    #Put stuff in printer begins with word 'Sold' into seller field

    df_new=df_gesamt.printer.str.extract('(?P<seller_y> ?[Ssh]ou?lde?.*)',expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                     join ='outer')
    mask = df_gesamt['seller_y'].notnull()
    df_gesamt['seller'][mask] = df_gesamt['seller_y'][mask]
    df_gesamt['printer'][mask]=''
    df_gesamt.drop('seller_y', inplace=True,axis=1)
    
    # Create new col printer to- for institutional affiliations
    df_new=df_gesamt.printer.str.extract(
    '(?P<printer_y>.*?)(?P<printer_to>(?:,? [Pp][ir][iye]nters? to).*)'
    ,expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                     join ='outer')
    mask = df_gesamt['printer_y'].notnull()
    df_gesamt['printer'][mask] = df_gesamt['printer_y'][mask]
    df_gesamt.drop('printer_y', inplace=True,axis=1)
    
    #split publisher field along location infos
    df_new=df_gesamt.publisher.str.extract(
    r'(?P<publisher_y>.*?)(?P<publisher_location>(?:\b[Ii]n\b|\b[Aa]t\b|\b[Ww]ithin\b|\b[Nn]eare?\b|\b[Dd]w[ey]ll[iy]nge?\b|\b[Aa]gainst\b|\b[Oo]ver\b|\b[Uu]nder\b).*)'
    ,expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')

    mask = df_gesamt['publisher_y'].notnull()
    df_gesamt['publisher'][mask] = df_gesamt['publisher_y'][mask]
    #mask = ~(df_gesamt['publisher_location_y'].isnull())
    #df_gesamt['publisher_location'][mask] = df_gesamt['printer_location_y'][mask]
    df_gesamt.drop(['publisher_y'],axis=1, inplace=True)
    
    #split stuffs in seller field based on location info
    df_new=df_gesamt.seller.str.extract(
    r'(?P<seller_y>.*?)(?P<seller_location>(?:\b[Ii]n\b|\b[Aa]t\b|\b[Ww]ithin\b|\b[Nn]e[ea]re?\b|\b[Dd]w[ey]ll[iy]nge?\b|\b[Aa]gainst\b|\b[Oo]ver\b|\b[Uu]nder\b).*)'
    ,expand=True)
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')
    mask = df_gesamt['seller_y'].notnull()
    df_gesamt['seller'][mask] = df_gesamt['seller_y'][mask]
    df_gesamt.drop(['seller_y'],axis=1, inplace=True)
    
    #put stuff in seller_location after by into seller col
    probs=df_gesamt[df_gesamt.seller_location.fillna('').str.contains(' by 'or' by ')&~(df_gesamt.seller.fillna('').str.contains(' by 'or' by '))]
    df_new=probs.seller_location.str.extract(r'(?P<seller_location_y>^(?:.*))(?P<seller_y> ?\b[Bb]y\b,?.*)')
    df_gesamt = pd.concat([df_gesamt,df_new], axis=1,
                      join ='outer')
    mask = df_gesamt['seller_location_y'].notnull()
    df_gesamt['seller'][mask] = df_gesamt['seller'][mask]+df_gesamt['seller_y'][mask]
    df_gesamt['seller_location'][mask] = df_gesamt['seller_location_y'][mask]
    df_gesamt.drop(['seller_y','seller_location_y'],axis=1, inplace=True)
    
    #replace By, printed by with empty string
    df_gesamt.printer=df_gesamt.printer.str.replace('By ?','')
    df_gesamt.printer=df_gesamt.printer.str.replace('([EeIij][mn])?[Pp][ir][iye]nt[ye]d (by )?','')
    df_gesamt.to_csv('df_gesamt.csv')
    return df_gesamt

# %%
pd.set_option('max_colwidth',150)

# %%
## Final results
# Out:
#                                                                                                              printer  \
# 0                                                                                                             G. Eld
# 1                                                                                        with licence by A. Conincx,
# 2                                                                                                      Richard Field
# 3                                                                                                           B. Alsop
# 4                                                                                                            Printed
# 5                                                                                                           I. Okes,
# 6
# 7                                                                                                           J. Bill,
# 8                                                                                                         J. Barnes,
# 9                                                                                                   Wynkyn de Worde,
# 10                            Typis Ioannis Wecheli, sumtibus vero Theodori de Bry anno M D XC. Venales reperiuntur
# 11                                                                                            Newly Henry Middleton,
# 12                                                                                                   Felix Kyngston,
# 13                       by Wynkyn de Worde. prynter vnto ye moost excellent pryncesse my lady the kynges graundame,
# 14                                                                                               by Wynkyn de Worde,
# 15     Newely perused and Iohn Wayland, aucthorised a prynter, by the Quenes highnes most gracious letters patentes,
# 16                                                                                                        R. Barker,
# 17                                                                                                    Iohn Hauiland,
# 18                                                                                                  Wynkyn de worde,
# 19                                                                                                    by Iohn Allde,
# 20                                                                                         J. Poullain and A. Rebul,
# 21                                                                                                       Abel Ieffes
# 22                                                                                                  Wynkyn de Worde,
# 23                                                                                                 Henrie Middleton,
# 24                                                                                                    Edward Griffin
# 25                                                                                          Iohn Charlwoode and i.e.
# 26                                                                                          A. Conincx with licence,
# 27                                                                                                     Thomas Thomas
# 28                                                                                                  Robert Robinson,
# 29                                                                                                  Ralph Hodgkinson
# ...                                                                                                              ...
# 60296
# 60297                                                                                                     T. Harper,
# 60298                                                                                               Wyllyam Copland,
# 60299                                                                                                    Thomas Est
# 60300                                                                                          English secret press,
# 60301                                                                                                        Printed
# 60302                                                                                                       E. Allde
# 60303                                                                              Hillebrany Iacobson i.e. B. Alsop
# 60304                                                                                            Eliot's Court Press
# 60305                                                                                                        Printed
# 60306                                                                                                       E. Allde
# 60307                                                                                                   N. Bohmberg,
# 60308                                                                                                  by W. Stansby
# 60309                                                                                                    Adam Islip,
# 60310                                                                                              Anthony Scoloker
# 60311                                                                            by Thomas Raynold and Wylliam Hyll,
# 60312                                                                                                           V.S.
# 60313                                                                                                           V.S.
# 60314                                                                                                     T. Snodham
# 60315                                                                                                E. Purslowe and
# 60316
# 60317                                                                                                   W. de Worde,
# 60318                                                                                         Apud Thomam Purfutium,
# 60319                                                                                                   Thomas East
# 60320                                                                                                    Peter Short
# 60321                                                                                                  Peter Short,
# 60322
# 60323                                                                                                 Cantrell Legge
# 60324                                                                                              Anthony Scoloker
# 60325                                                                                                Iohn Wreittoun,
#
#                                         publisher  \
# 0                           for Roger Barnes, and
# 1                                             NaN
# 2                            for Felix Norton and
# 3                       for Nathaniel Butter, and
# 4                for Henry Tomes i.e. W. Jaggard,
# 5                           for Humphrey Mosley,
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                              for Ralph Iacson,
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                            for William Barret,
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                 for T. Gubbin and Iohn Busbie,
# 22                                            NaN
# 23                              for Iohn Harison,
# 24                       for Laurence L'isle, and
# 25                            for Simon Waterson,
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                          for Daniel Frere, and
# ...                                           ...
# 60296           For Nat. Butter, and Nic. Bourne,
# 60297                                         NaN
# 60298                                         NaN
# 60299                                         NaN
# 60300                                         NaN
# 60301                     for Philip Harison, and
# 60302                      for Thomas Archer, and
# 60303                                         NaN
# 60304    for Nathaniel Butter, and Thomas Archer,
# 60305        for Nath Butter and Nicholas Bourne,
# 60306  for Nicholas Bourne and Thomas Archer, and
# 60307                                         NaN
# 60308                        for W. Barrett?, and
# 60309                                         NaN
# 60310                                         NaN
# 60311                                         NaN
# 60312                      for Thomas Pauier, and
# 60313                              for T. Pavier,
# 60314                              for N. Bourne,
# 60315                                         NaN
# 60316                           For T. Cotes, and
# 60317                                         NaN
# 60318                                         NaN
# 60319                                         NaN
# 60320                       for William Ponsonby,
# 60321                                         NaN
# 60322                                         NaN
# 60323                                         NaN
# 60324                                         NaN
# 60325                                         NaN
#
#                                                                                                                     seller  \
# 0                                                                                                             are to sold
# 1                                                                                                                      NaN
# 2                                                                                                          are to be sold
# 3                                                                                                          are to be sold
# 4                                                                                                                      NaN
# 5                                                                                                                      NaN
# 6                                                                                                                      NaN
# 7                                                                                                                      NaN
# 8                                                                                                                      NaN
# 9                                                                                                                      NaN
# 10                                                                                                                     NaN
# 11                                                                                                                     NaN
# 12                                                                                                                     NaN
# 13                                                                                                                     NaN
# 14                                                                                                                     NaN
# 15                                                                                                                     NaN
# 16                                                                                                                     NaN
# 17                                                                                                                     NaN
# 18                                                                                                                     NaN
# 19                                                                                                                     NaN
# 20                                                                                                                     NaN
# 21                                                                                                                     NaN
# 22                                                                                                                     NaN
# 23                                                                                                                     NaN
# 24                                                                                                        are to bee sold
# 25                                                                                                                     NaN
# 26                                                                                                                     NaN
# 27                                                                                                                     NaN
# 28                                                                                                                     NaN
# 29                                                                                                         are to be sold
# ...                                                                                                                    ...
# 60296                                                                                                                  NaN
# 60297                                                                                                                  NaN
# 60298                                                                                                                  NaN
# 60299                                                                                                                  NaN
# 60300                                                                                                                  NaN
# 60301                                                                                                     are to be solde
# 60302                                                                                                      are to be sold
# 60303                                                                                                                  NaN
# 60304                                                                                                                  NaN
# 60305                                                                                                                  NaN
# 60306                                                                                                      are to be sold
# 60307                                                                                                                  NaN
# 60308                                                                                   are to bee sold by Edvvard Wright
# 60309                                                                                                                  NaN
# 60310                                                                                                                  NaN
# 60311                                                                                                                  NaN
# 60312                                                                                                      are to be sold
# 60313                                                                                                                  NaN
# 60314                                                                                                                  NaN
# 60315   are to be sold betweene Douer Cliffe, and Barwicke Bridge. An. 12000. Or else are to bee sold by Stephen Pemmell,
# 60316                                                                                  are to be sold b sic F. Groves ...,
# 60317                                                                                                                  NaN
# 60318                                                                                                                  NaN
# 60319                                                                                                                  NaN
# 60320                                                                                                                  NaN
# 60321                                                                                                                  NaN
# 60322                                                                                                                  NaN
# 60323                                                                                     are to be sold by Samuel Macham
# 60324                                                                                                                  NaN
# 60325                                                                                                                  NaN
#
#           key  \
# 0      A00648
# 1      A00908
# 2      A01003
# 3      A01076
# 4      A01086
# 5      A01446
# 6      A01639
# 7      A01809
# 8      A01812
# 9      A01907
# 10     A02655
# 11     A02657
# 12     A02797
# 13     A02811
# 14     A02813
# 15     A02817
# 16     A04242
# 17     A04495
# 18     A04792
# 19     A04894
# 20     A04928
# 21     A06173
# 22     A06570
# 23     A06869
# 24     A08597
# 25     A09086
# 26     A09097
# 27     A09659
# 28     A10354
# 29     A10368
# ...       ...
# 60296  A07533
# 60297  A07589
# 60298  A07665
# 60299  A07744
# 60300  A07808
# 60301  A08092
# 60302  A08096
# 60303  A08103
# 60304  A08138
# 60305  A08144
# 60306  A08155
# 60307  A08216
# 60308  A08432
# 60309  A08520
# 60310  A08523
# 60311  A08524
# 60312  A08572
# 60313  A08573
# 60314  A08930
# 60315  A08966
# 60316  A08985
# 60317  A09012
# 60318  A09019
# 60319  A09631
# 60320  A09724
# 60321  A09731
# 60322  A09748
# 60323  A09759
# 60324  A09921
# 60325  A09957
#
#                                                                               printer_location  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3                                                                                          NaN
# 4                                                                                          NaN
# 5                                                                                          NaN
# 6                                                               In officina Iohannis Haviland,
# 7                                                                                          NaN
# 8                                                                                          NaN
# 9                                                                                          NaN
# 10                                                         in officina Sigismundi Feirabendii,
# 11                                                                                         NaN
# 12                                                                                         NaN
# 13                                                  In flete strete at the sygne of the sonne
# 14                                                                                         NaN
# 15                                                                                         NaN
# 16                                                                                         NaN
# 17                                                                                         NaN
# 18                                                                             in Fletestrete
# 19                          At the long shop adioyning vnto S. Mildreds Church in the Pultrie
# 20                                                                                         NaN
# 21                                                                                         NaN
# 22                                        in London in Flete Strete in the sygne of the Conne
# 23                                                                                         NaN
# 24                                                                                         NaN
# 25                                                                                         NaN
# 26                                                                                         NaN
# 27                                                                                         NaN
# 28                                                                                         NaN
# 29                                                                                         NaN
# ...                                                                                        ...
# 60296                                                                                      NaN
# 60297                                                                                      NaN
# 60298                                                                                      NaN
# 60299                                    in Aldersgate street at the signe of the black horse,
# 60300                                                                                      NaN
# 60301                                                                                      NaN
# 60302                                                                                      NaN
# 60303                                                                                      NaN
# 60304                                                                                      NaN
# 60305                                                                                      NaN
# 60306                                                                                      NaN
# 60307                                                                                      NaN
# 60308                                                                                      NaN
# 60309                                                                                      NaN
# 60310  dwelling in the Sauoy rentes. Without Templebarre. Cum priuilegio ad imprimendum solum,
# 60311                                        In saynt Andrews paryshe besyde Baynards castell
# 60312                                                                                      NaN
# 60313                                                                                      NaN
# 60314                                                                                      NaN
# 60315                                                                                      NaN
# 60316                                                                                      NaN
# 60317                                                                                      NaN
# 60318                                                                                      NaN
# 60319                                                          dwelling in Aldersgate streete,
# 60320                                                                                      NaN
# 60321                                  dwelling at the signe of the Starre on Bredstreet hill,
# 60322                                            at Eliot's Court press impensis Ioannis Bill,
# 60323                                                                                      NaN
# 60324                                        dwelling in the Sauoy rents. Wythout Templebarre,
# 60325                                                                                      NaN
#
#                                                  printer_to  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                                                       NaN
# 10                                                      NaN
# 11                                                      NaN
# 12                                                      NaN
# 13                                                      NaN
# 14                                                      NaN
# 15                                                      NaN
# 16                                                      NaN
# 17                                                      NaN
# 18                                                      NaN
# 19                                                      NaN
# 20                                                      NaN
# 21                                                      NaN
# 22                                                      NaN
# 23                                                      NaN
# 24                                                      NaN
# 25                                                      NaN
# 26                                                      NaN
# 27                 printer to the Vniuersitie of Cambridge,
# 28                                                      NaN
# 29                                                      NaN
# ...                                                     ...
# 60296                                                   NaN
# 60297                                                   NaN
# 60298                                                   NaN
# 60299                                                   NaN
# 60300                                                   NaN
# 60301                                                   NaN
# 60302                                                   NaN
# 60303                                Printer to the States,
# 60304                                                   NaN
# 60305                                                   NaN
# 60306                                                   NaN
# 60307                                                   NaN
# 60308                                                   NaN
# 60309                                                   NaN
# 60310                                                   NaN
# 60311                                                   NaN
# 60312                                                   NaN
# 60313                                                   NaN
# 60314                                                   NaN
# 60315                                                   NaN
# 60316                                                   NaN
# 60317                                                   NaN
# 60318                                                   NaN
# 60319                                                   NaN
# 60320                                                   NaN
# 60321                                                   NaN
# 60322                                                   NaN
# 60323  , printer to the Vniuersitie of Cambridge. 1609. And
# 60324                                                   NaN
# 60325                                                   NaN
#
#                                publisher_location  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5      at the Princes Armes in Pauls Church-Yard,
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ...                                           ...
# 60296                                         NaN
# 60297                                         NaN
# 60298                                         NaN
# 60299                                         NaN
# 60300                                         NaN
# 60301                                         NaN
# 60302                                         NaN
# 60303                                         NaN
# 60304                                         NaN
# 60305                                         NaN
# 60306                                         NaN
# 60307                                         NaN
# 60308                                         NaN
# 60309                                         NaN
# 60310                                         NaN
# 60311                                         NaN
# 60312                                         NaN
# 60313                                         NaN
# 60314                                         NaN
# 60315                                         NaN
# 60316                                         NaN
# 60317                                         NaN
# 60318                                         NaN
# 60319                                         NaN
# 60320                                         NaN
# 60321                                         NaN
# 60322                                         NaN
# 60323                                         NaN
# 60324                                         NaN
# 60325                                         NaN
#
#                                                             seller_location
# 0                    at his shop in S. Dunstans Church-yard in Fleetstreet,
# 1                                                                       NaN
# 2                          in Pauls Church-yard at the signe of the Parrot,
# 3                  at his shop, at the Pyed Bull, neere Saint Austens Gate,
# 4                                                                       NaN
# 5                                                                       NaN
# 6                                                                       NaN
# 7                                                                       NaN
# 8                                                                       NaN
# 9                                                                       NaN
# 10                                                                      NaN
# 11                                                                      NaN
# 12                                                                      NaN
# 13                                                                      NaN
# 14                                                                      NaN
# 15                                                                      NaN
# 16                                                                      NaN
# 17                                                                      NaN
# 18                                                                      NaN
# 19                                                                      NaN
# 20                                                                      NaN
# 21                                                                      NaN
# 22                                                                      NaN
# 23                                                                      NaN
# 24                     at his shop at the Tigers head in Pauls Church-yard,
# 25                                                                      NaN
# 26                                                                      NaN
# 27                                                                      NaN
# 28                                                                      NaN
# 29                                      at the red-Bull in little-Brittain,
# ...                                                                     ...
# 60296                                                                   NaN
# 60297                                                                   NaN
# 60298                                                                   NaN
# 60299                                                                   NaN
# 60300                                                                   NaN
# 60301          at the little shop at the Exchange ouer against the Conduit,
# 60302                                      at his shop in Popes-head Alley,
# 60303                                                                   NaN
# 60304                                                                   NaN
# 60305                                                                   NaN
# 60306            at their shops at the Exchange, and in Popes-head Pallace,
# 60307                                                                   NaN
# 60308                                                at Christ-Church gate,
# 60309                                                                   NaN
# 60310                                                                   NaN
# 60311                                                                   NaN
# 60312  at his shop in Cornehill, at the signe of the catte and two parrots,
# 60313                                                                   NaN
# 60314                                                                   NaN
# 60315                   at the blacke Bull neere the gate on London Bridge,
# 60316                                                                   NaN
# 60317                                                                   NaN
# 60318                                                                   NaN
# 60319                                                                   NaN
# 60320                                                                   NaN
# 60321                                                                   NaN
# 60322                                                                   NaN
# 60323           in Pauls Churchyard , London at the signe of the Bull head,
# 60324                                                                   NaN
# 60325                                                                   NaN
#
# [60326 rows x 8 columns]
