# %%
import os

# %%
os.chdir('/Users/chenzhikai/AnacondaProjects/2017 Summer Research/Data Cleanup/')

# %%
import RegexLibrary as rl

# %%
rl.preproccess()
# Out:
# RegexLibrary.py:118: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# RegexLibrary.py:196: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
database=to_relational_database()
# Out:
# RegexLibrary.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# RegexLibrary.py:272: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# RegexLibrary.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# RegexLibrary.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
database
# Out:
#           key                   actor     role
# 0      A00648                  G. Eld  printer
# 1      A01003           Richard Field  printer
# 2      A01076                B. Alsop  printer
# 3      A01446                 I. Okes  printer
# 4      A01809                 J. Bill  printer
# 5      A01812               J. Barnes  printer
# 6      A02797          Felix Kyngston  printer
# 7      A04242               R. Barker  printer
# 8      A04495           Iohn Hauiland  printer
# 9      A04894              Iohn Allde  printer
# 10     A04928             J. Poullain  printer
# 11     A04928                A. Rebul  printer
# 12     A06173             Abel Ieffes  printer
# 13     A06869        Henrie Middleton  printer
# 14     A08597          Edward Griffin  printer
# 15     A09659           Thomas Thomas  printer
# 16     A10354         Robert Robinson  printer
# 17     A10368        Ralph Hodgkinson  printer
# 18     A10376             John Windet  printer
# ...

# %%
database.groupby(['role'])['actor'].value_counts().sort_values(ascending=False)
# Out:
# role       actor
# publisher  the author                                     766
# printer    Robert Barker                                  502
# publisher  Giles Calvert                                  370
# printer     Christopher Barker                            347
#            Leonard Lichfield                              304
#             Thomas Newcomb                                295
#             Henry Hills                                   280
# publisher  Tho. Parkhurst                                 275
#            Walter Kettilby                                267
# printer    Evan Tyler                                     265
# publisher  F. Coles                                       254
# printer    Henry Hills                                    253
#            John Bill                                      251
#             Iohn Bill                                     249
# publisher  Thomas Simmons                                 239
# ...
